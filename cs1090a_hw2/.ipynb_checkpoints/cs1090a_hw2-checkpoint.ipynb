# %%
# Initialize Otter
import otter
grader = otter.Notebook("cs1090a_hw2.ipynb")

# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> CS1090A Introduction to Data Science
# ## Homework 2: kNN and Linear Regression
#
# **Harvard University**<br/>
# **Fall 2024**<br/>
# **Instructors**: Pavlos Protopapas, Natesh Pillai, and Chris Gumb
#
# <hr style="height:2.4pt">

# %%
# RUN THIS CELL 
import requests
from IPython.core.display import HTML
styles = requests.get(
    "https://raw.githubusercontent.com/Harvard-IACS/2021-CS109A/master/"
    "themes/static/css/cs109.css"
).text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #63ACBE;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #f8b4ab;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# }
#
# div.exercise-r {
# 	background-color: #ffd0d0;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# }
#
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #63ACBE;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #601A4A;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
#     padding-top: 5px;
#     padding-bottom: 5px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
# header {
#    padding-top: 35px;
#     padding-bottom: 35px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# span.emph {
# 	color: #601A4A;
# 	font-weight: bold;
# }
#
# </style>

# %% [markdown]
# <div style = "background: lightgreen; border: thin solid black; border-radius: 2px; padding: 5px">
#
# ### Instructions
# - To submit your notebook, follow the instructions given in on the Canvas assignment page.
# - Plots should be legible and interpretable *without having to refer to the code that generated them*. They should include labels for the $x$- and $y$-axes as well as a descriptive title and/or legend when appropriate.
# - When asked to interpret a visualization, do not simply describe it (e.g., "the curve has a steep slope up"), but instead explain what you believe the plot *means*.
# - Autograding tests are mostly to help you debug. The tests are not exhaustive so simply passing all tests may not be sufficient for full credit.
# - The use of *extremely* inefficient or error-prone code (e.g., copy-pasting nearly identical commands rather than looping) may result in only partial credit.
# - We have tried to include all the libraries you may need to do the assignment in the imports cell provided below. Please get course staff approval before importing any additional 3rd party libraries.
# - Enable scrolling output on cells with very long output. Or better yet, avoid overly long output altogether.
# - Feel free to add additional code or markdown cells as needed.
# - Don't forget to include a written response when one is requested by a question prompt.
# - Ensure your code runs top to bottom without error and passes all tests by restarting the kernel and running all cells (note that this can take a few minutes).
# - **You should do a "Restart Kernel and Run All Cells" before submitting to ensure (1) your notebook actually runs and (2) all output is visible**
# </div>

# %%
# RUN THIS CELL
# Import libraries
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
import time

# pandas tricks for better display
pd.options.display.max_columns = 50  
pd.options.display.max_rows = 500     
pd.options.display.max_colwidth = 100
pd.options.display.precision = 3

# %%
# For calculating total notebook runtime
notebook_start = time.time()

# %% [markdown]
# <a id="contents"></a>
#
# ## Notebook Contents
#
# - [**PART 1 [50 pts]: Predicting the selling price of cars on CarDekho.com**](#part1)
#   - [Part 1 Overview](#part1intro)
#   - [Question 1: Exploratory data analysis (EDA) [5 pts]](#part1questions)
#   - [Question 2: k-Nearest Neighbors [20 pts]](#part2questions)
#   - [Question 3: Simple linear regression [25 pts]](#part3questions)
#
#
# - [**PART 2 [50 pts]: Analysis of Simulated ASEC Data**](#part2)
#   - [Part 2 Overview](#part2intro)
#   - [Question 4:   Investigating trends [30 pts]](#part4questions)
#   - [Question 5:  Calculate the Gini coefficient [10 pts]](#part5questions)
#   - [Question 6:  Critiquing the simulated data [10 pts]](#part6questions)

# %% [markdown]
# ## About this homework
#
# This assignment is the first in which we'll go through the process of loading a dataset, splitting it into train and test sets, performing some preprocessing, and finally fitting some models and evaluating our results.
#
# We have two different datasets:
# - [**PART 1**](#part1) car data from [cardekho.com](https://www.cardekho.com/)
# - [**PART 2**](#part2) *simulated* income data created from the [Annual Social and Economic (ASEC) Supplement](https://www.census.gov/data/datasets/time-series/demo/cps/cps-asec.html)
#
# Part 1 explores two simple methods for prediction,  **k-nearest neighbors regression (kNN)**, a *non-parametric* method, and **linear regression**, a *parametric* method.
#
# Part 2 is focused EDA and visualization.

# %% [markdown]
# <a id="part1"></a>
#
# # PART 1 [50 pts]: Predicting the selling price of cars on CarDekho.com
#
# [Return to contents](#contents)

# %% [markdown]
# <a id="part1intro"></a>
#
# ## Overview
#
# [Return to contents](#contents)
#
# According to its website, **CarDekho.com** is India's leading car search venture. Its website and app carry rich automotive content such as expert reviews, detailed specs and prices, comparisons, as well as videos and pictures of all car brands and models available in India. Each car has a **current selling price**, which is the price for buying a used car on this site, and an **MRP**, which is the retail price of the car. These two prices differ depending on factors such as brand, make year, mileage, condition, etc.
#
# ### Dataset
#
# The dataset contains 601 used cars and is available as `data/car_dekho_full.csv`. It contains the following columns:
#
# - **Year** - make year (year the car was made),
# - **Current_Selling_Price** - current price of a used car on CarDekho.com (in lakhs),
# - **MRP** - maximum retail price of the car when it was new (in lakhs).
# - **Kms_Driven** - number of kilometers
#
# **NOTE:** 1 *lakh*  is 100,000 Rupees in the Indian numbering system. Also, kilometers are used as a measure of distance instead of miles.
#
# ### Objective
#
# Using kNN and linear regression we will predict the `Current_Selling_Price` from the other features available in this dataset.

# %% [markdown]
# <a id="part1questions"></a>
#
# ## <div class='exercise'><b> Question 1: Exploratory data analysis (EDA) [5 pts]</b></div>
#
# [Return to contents](#contents)
#
# To reach the goal of predicting the `Current_Selling_Price`, start by inspecting the dataset using Exploratory Data Analysis (EDA).
#
# **Load the dataset, inspect it, and answer the following questions:**

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q1.1</b></div>

# %% [markdown]
# Identify all variables in the dataset. For each variable, state whether you consider it to be quantitative or categorical and briefly justify your choices.

# %% [markdown]
# <font color = blue> `Year`: **Quantitative** -> Year can be treated as a discrete quantitative variable because there is an inherent ordering in the years. A more recent car would be more vaulable (in `Current_Selling_Price`) than an older car. </font>
#
# <font color = blue> `Current_Selling_Price`: **Quantitative** -> This variable represents a continuous numerical value measured in currency units, making it a quantitative variable</font>
#
# <font color = blue> `MRP`: **Quantitative** -> Similar to Current_Selling_Price, MRP (Manufacturer's Recommended Price) is a continuous numerical value measured in currency units</font>
#
# <font color = blue> `Kms_Driven`: **Quantitative** -> This variable represents a continuous numerical measurement of distance traveled, making it a quantitative variable</font>

# %%
# your code here
car = pd.read_csv('data/car_dekho_full.csv')
print(car.describe())
car.head()
# Out:
#            Year  Current_Selling_Price      MRP  Kms_Driven
# count   601.000                601.000  601.000     601.000
# mean   2013.887                  4.393    6.912   33718.745
# std       2.721                  4.518    6.480   26846.657
# min    2003.000                  0.120    0.320     500.000
# 25%    2012.000                  1.050    1.470   15000.000
# 50%    2015.000                  3.600    6.050   30000.000
# 75%    2016.000                  5.800    9.400   46500.000
# max    2018.000                 33.000   36.230  213000.000
#    Year  Current_Selling_Price    MRP  Kms_Driven
# 0  2016                   5.25   5.70        3493
# 1  2005                   3.51  13.70       75000
# 2  2010                   0.31   1.05      213000
# 3  2006                   2.10   7.60       50456
# 4  2005                   0.20   0.57       55000

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q1.2</b></div>

# %% [markdown]
# The goal in this section is to identify the best feature to use to predict our response, `Current_Selling_Price`.
#
# - Plot a scatter plot of each feature and our reponse and examine any relationships.
# - Which is the predictor that seems to best predict `Current_Selling_Price`? Provide an interpretation of the plots that justifies your choice.

# %% [markdown]
# ## ANSWER
#
# <font color='blue'>The predictor that seems to best predict Current_Selling_Price is **MRP (Manufacturer's Recommended Price)**. </font>
#
# <font color='blue'>This conclusion is based on the following interpretation of the scatter plots:
#
# 1. <font color='blue'> The MRP vs. Current_Selling_Price plot shows the clearest and strongest linear relationship among all features examined.</font>
#
# 2. <font color='blue'>There's appears to be very strong positive correlation between MRP and current selling price, with data points closely following a diagonal line.</font>
#
# 3. <font color='blue'>While Year and Kms_Driven do show relationships with Current_Selling_Price, these relationships are not as strong or clear as the one with MRP. For example, while Current Selling Price does seem to increase with Year (when car was made), There is a lot of variability within each year.</font>
#
# 4. <font color='blue'>The MRP likely incorporates many factors that influence a car's value, such as the model, features, and initial quality, which could explain its strong predictive power.</font>
#
# 5. <font color='blue'>It's logical that MRP would be the best predictor, as the current selling price is often based on the original price with some depreciation factored in.</font>
#
# <font color='blue'>In summary, MRP stands out as the strongest predictor due to its clear linear relationship and tight clustering of data points, suggesting it would be the most reliable single feature for predicting the current selling price of a car in this dataset.</font>

# %%
# your code here
fig, axs = plt.subplots(3, 1, figsize=(12, 10))

sns.scatterplot(data=car, x='Year', y='Current_Selling_Price', hue='Current_Selling_Price', s=25, ax=axs[0]).set_title('Current Selling Price vs. Year')
sns.scatterplot(data=car, x='MRP', y='Current_Selling_Price', hue='Current_Selling_Price', s=25, ax=axs[1]).set_title('Current Selling Price vs. MRP')
sns.scatterplot(data=car, x='Kms_Driven', y='Current_Selling_Price', hue='Current_Selling_Price', s=25, ax=axs[2]).set_title('Current Selling Price vs. KMS_Driven')

plt.suptitle('Different Current Selling Price Trends')
plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <a id="part2questions"></a>
#
# ## <div class='exercise'><b> Question 2:   k-Nearest Neighbors [20 pts]</b></div>
#
# [Return to contents](#contents)
#
# We will begin our modeling with k-Nearest Neighbors (kNN) regression, using `sklearn` for both preprocessing and model fitting.

# %% [markdown]
# <div class='exercise'><b>Q2.1</b></div>

# %% [markdown]
# Split the dataset into a train and test set with 75% training data and 25% testing data, using argument `random_state = 109`. The resulting splits should be stored in the variables `X_train`, `X_test`, `y_train`, `y_test`.

# %%
# your code here
X = car[['MRP']]
y = car['Current_Selling_Price']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, shuffle=True, random_state=109)

# %%
grader.check("q2.1")
# Out:
# q2.1 results: All test cases passed!

# %% [markdown]
# <div class='exercise'><b>Q2.2</b></div>

# %% [markdown]
# Now, we will fit several kNN regression models for various values of $k$ to identify the best parameterization.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q2.2.1</b></div>

# %% [markdown]
# For each $k$ in $k \in [1,2,3,5,7,10,50,100]$, fit a k-NN regression model to the training data with response `Current_Selling_Price` and the predictor `MRP`.
#   - For each $k$, make a plot of reponse vs. predictor (8 plots in total, arranged in a 4×2 grid).
#   - Each of your 8 plots should clearly show (a) the training data and the testing data in different colors, (b) the model prediction, and (c) title, legend, and axis labels.
#   - **NOTE:** Feel free to use the `plt.subplots()` code we provide to specify your 4x2 grid, unless you first try that and decide that you have a clearer, cleaner way of accomplishing this task.

# %%
# your code here
predictors = []
ks = [1,2,3,5,7,10,50,100]
X_lin = np.linspace(X.min(), X.max(), 1000)
X_lin = pd.DataFrame(X_lin, columns=['MRP'])

for k in ks:
    knn = KNeighborsRegressor(n_neighbors=k).fit(X_train, y_train).predict(X_lin)
    predictors.append(knn)
fig, axs = plt.subplots(nrows=4, ncols=2, figsize=(12,14))
fig.subplots_adjust(hspace = .4, wspace=.2)
axs = axs.ravel()
for k, predictor, ax in zip(ks, predictors, axs):
    ax.scatter(X_train, y_train, alpha=0.45, label='train')
    ax.scatter(X_test, y_test, alpha=0.45, label='test')
    ax.plot(X_lin, predictor, c='k', label='predictions');
    ax.set_xlabel('MRP')
    ax.set_ylabel('Current_Selling_Price')
    ax.set_title(f'kNN Regression Model (k={k})')
    ax.legend();

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q2.2.2</b></div>

# %% [markdown]
# Plot the training and test $MSE$ values as a function of $k$ (1 plot in total).

# %%
train_mses = []
test_mses = []
for k in ks:
    cur_knn = KNeighborsRegressor(n_neighbors=k).fit(X_train, y_train)
    train_mses.append(mean_squared_error(y_train, cur_knn.predict(X_train)))
    test_mses.append(mean_squared_error(y_test, cur_knn.predict(X_test)))
best_idx = np.argmin(test_mses)
best_k = ks[best_idx]
plt.plot(ks, train_mses, label='train')
plt.plot(ks, test_mses, label='test')
plt.axvline(best_k, c='k', ls='--', label=rf'best $k$={best_k}')
plt.xlabel(r'$k$')
plt.ylabel('MSE')
plt.title('kNN MSE loss as a function of $k$')
plt.legend();

# %% [markdown]
# <!-- END QUESTION -->
#
# <div class='exercise'><b>Q2.2.3</b></div>

# %% [markdown]
# Find the best model based on the test $MSE$ values. Store the best $k$-value in `best_k` and the best test $MSE$ in `best_mse`.

# %%
# your code here
best_k = ks[best_idx]
best_mse = test_mses[best_idx]

# %%
print(
    f"The best k value is {best_k}. This corresponds to the "
    f"lowest test MSE of {best_mse:.3f}."
)
# Out:
# The best k value is 7. This corresponds to the lowest test MSE of 2.129.

# %%
grader.check("q2.2.3")
# Out:
# q2.2.3 results: All test cases passed!

# %% [markdown]
# <div class='exercise'><b>Q2.2.4</b></div>

# %% [markdown]
# Evaluate and report the $R^2$ of the best model. Save the $R^2$ of the best model in `best_r2`.

# %%
# your code here
best_model =  KNeighborsRegressor(n_neighbors=best_k).fit(X_train, y_train)
best_r2 = r2_score(y_test, best_model.predict(X_test))

# %%
print(
    f"The R-squared score evaluated on the test set for the best model "
    f"with k={best_k} is {best_r2:.4f}."
)
# Out:
# The R-squared score evaluated on the test set for the best model with k=7 is 0.8678.

# %%
grader.check("q2.2.4")
# Out:
# q2.2.4 results: All test cases passed!

# %% [markdown]
# <a id="part3questions"></a>
#
# ## <div class='exercise'><b>Question 3:  Simple linear regression [25 pts]</b></div>
#
# [Return to contents](#contents)

# %% [markdown]
# <div class='exercise'><b>Q3.1</b></div>

# %% [markdown]
# We will now fit our data using a linear regression model. Choose the same **predictor** and **response** variables you used in the kNN model. You will also use the same 75% training and 25% testing split of the data, which was created using `random_state = 109`.

# %% [markdown]
# <div class='exercise'><b>Q3.1.1</b></div>

# %% [markdown]
# Fit a linear regression model. Name your model `linreg`.

# %%
# your code here
# Instantiate a LinearRegression class object and fit with train data
linreg = LinearRegression().fit(X_train, y_train)

# %%
grader.check("q3.1.1")
# Out:
# q3.1.1 results: All test cases passed!

# %% [markdown]
# <div class='exercise'><b>Q3.1.2</b></div>

# %% [markdown]
# Report the slope and intercept values for the fitted linear model. Name your variables `slope` and `intercept`.

# %%
# your code here
slope = linreg.coef_[0]
intercept = linreg.intercept_

# %%
print(
    f"Intercept of the fitted linear model\t\t{intercept:.4f}\n"
    f"Slope of the fitted linear model\t{slope:.4f}"
)
# Out:
# Intercept of the fitted linear model		0.1124
# Slope of the fitted linear model	0.6157

# %%
grader.check("q3.1.2")
# Out:
# q3.1.2 results: All test cases passed!

# %% [markdown]
# <div class='exercise'><b>Q3.1.3</b></div>

# %% [markdown]
# Report the $MSE$ for the training and test sets and the $R^2$ for the test set. Name your variables `lin_train_mse`, `lin_test_mse`, and `lin_test_r2`.

# %%
# your code here 
# Compute the MSE of the model
lin_train_mse = mean_squared_error(y_train, linreg.predict(X_train))
lin_test_mse = mean_squared_error(y_test, linreg.predict(X_test))
# Compute the R-squared of the model
lin_test_r2 = r2_score(y_test, linreg.predict(X_test))

# %%
print("Linear regression model results:\n")
print(
    "\tTrain MSE\t{:.4f}\n"
    "\tTest MSE\t{:.4f}\n".format(
        lin_train_mse,
        lin_test_mse,
    )
)

print(f"\tTest R-squared\t{lin_test_r2:.4f}")
# Out:
# Linear regression model results:
#
# 	Train MSE	4.7133
# 	Test MSE	3.1362
#
# 	Test R-squared	0.8053

# %%
grader.check("q3.1.3")
# Out:
# q3.1.3 results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q3.1.4</b></div>

# %% [markdown]
# Create the following 3 plots:
# - Plot the **regression line** along with the **training data**.
# - Plot the **residuals** of the model on the **training** set as a function of the **predictor** variable. Draw a horizontal line denoting the zero residual value on the $y$-axis.
# - Plot a the **distribution** of the **residuals** on the **training** set.
#
# As always, your plots should be well-labeled.

# %%
# your code here 
y_hat_test = linreg.predict(X_test)
resids = y_test - y_hat_test
reg_line = intercept + X_lin * slope
fig, axs = plt.subplots(3, 1, figsize=(12, 10))

# Plot 1: Regression line with training data
axs[0].scatter(X_train, y_train, alpha=0.5)
axs[0].plot(X_lin, reg_line, color='red', label='Regression Line')
axs[0].set_xlabel('MRP')
axs[0].set_ylabel('Current Selling Price')
axs[0].set_title('Linear Regression: Current Selling Price vs MRP')
axs[0].legend()

# Plot 2: Residuals vs Predictor Variable
y_hat_train = linreg.predict(X_train)
resids_train = y_train - y_hat_train
axs[1].scatter(X_train, resids_train, alpha=0.5)
axs[1].axhline(0, color='red', linestyle='--')
axs[1].set_xlabel('MRP')
axs[1].set_ylabel('Residuals')
axs[1].set_title('Residuals vs MRP')

# Plot 3: Distribution of Residuals
axs[2].hist(resids_train, bins=30, edgecolor='black')
axs[2].set_xlabel('Residuals')
axs[2].set_ylabel('Frequency')
axs[2].set_title('Distribution of Residuals')

plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <div class='exercise'><b>Q3.2</b></div>
# Answer the following questions about your results:

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q3.2.1</b></div>

# %% [markdown]
# A linear regression model makes four important assumptions. For each assumption, describe how one or more of the plots in the previous question may provide evidence that (1) the assumption holds, (2) that the assumption is violated, or (3) that none of the plots have any bearing on the assumption.
#
# **Note:** Don't over-think this question! You are just being asked to use the plots above to check the four assumptions and to explain your reasoning.

# %% [markdown]
# 1. **Linearity:**
#    - The first plot (regression line with training data) shows a linear trend between MRP and Current Selling Price, indicating that the linearity assumption is reasonable.
#
# 2. **Independence:**
#    - None of the plots directly address independence. This assumption generally requires knowledge of the data collection process to ensure no autocorrelation.
#
# 3. **Homoscedasticity:**
#    - The second plot (residuals vs. MRP) shows a violation of homoscedasticity, as the spread of residuals increases with higher MRP values, indicating non-constant variance.
#
# 4. **Normality:**
#    - The third plot (distribution of residuals) suggests approximate normality, but the histogram's shape should ideally be more symmetric and bell-shaped for stronger evidence.

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q3.2.2</b></div>

# %% [markdown]
# Based on what you have seen in the preceding questions, which model would you select as the best and why? Might you have any reason to doubt your choice? Why or why not?
#
# **Hint:** There were more than just 2 candidate models.

# %% [markdown]
# <font color = blue>Based on the analysis of the models, I would select the **k-NN model** as the best choice for predicting Current Selling Price. Here's why:</font>
#
# 1.<font color = blue> **Model Fit:**
#    - The k-NN model, particularly with `k = 7`, captures the non-linear relationship between MRP and Current Selling Price, especially towards the tail end. This is evident from the lower MSE test score, compared to linear regression.</font>
#
# 2.<font color = blue> **Linear Regression Limitations:**
#    - The linear regression model struggles with higher MRP values, as shown by increasing residuals and a lack of homoscedasticity (in the residuals). This suggests that a simple linear model may not adequately capture the complexity of the data.</font>
#
# 3. <font color = blue>**Preference for Linear Regression at Low MRP:**
#    - Despite its limitations, I prefer the linear regression model's performance at lower MRP values, where it provides a straightforward interpretation and fits well.</font>
#
# 4. <font color = blue>**Reservations about k-NN:**
#    - While k-NN performs well, it may be sensitive to noise and outliers, especially with high variance in data. Additionally, selecting an optimal `k` value can be challenging and might not generalize well to unseen data. Moreover, its graph is very questionable. Furthermore, if we applied cross validation, we could have been more certain on whether `k=7`.</font>
#
# 5.<font color = blue> **Potential for Other Models:**
#    - Considering a polynomial regression model could further improve fit by accommodating non-linear patterns without the sensitivity issues of k-NN.</font>
#
# <font color = blue>In conclusion, while k-NN appears to be the best choice given its flexibility and fit to the data, careful consideration of its limitations and exploration of alternative models like polynomial regression could enhance predictive accuracy.</font>

# %% [markdown]
# <!-- END QUESTION -->
#
# <a id="part2"></a>
#
# # PART 2 [50 pts]: Analysis of 2024 US Annual Social and Economic (ASEC) Supplement
#
# [Return to contents](#contents)

# %% [markdown]
# <a id="part2intro"></a>
#
# ## Overview
#
# [Return to contents](#contents)
#
# In this part we analyze *simulated* income data from the publically available 2024 US Annual Social and Economic (ASEC) Supplement (https://www.census.gov/data/datasets/time-series/demo/cps/cps-asec.html), provided by the US Census Bureau. The Current Population Survey (CPS) has been conducted monthly for over 50 years. Currently, about 54,000 households are interviewed monthly, scientifically selected on the basis of area of residence to represent the nation as a whole, individual states, and other specified areas.
#
# ### Dataset
#
# The simulated data can be found in `data/census_data.csv`.
#
# The number of features have been greatly reduced from the original dataset. You can see the description of the original dataset in the [ASEC data dictionary](https://www2.census.gov/programs-surveys/cps/datasets/2024/march/asec2024_ddl_pub_full.pdf).
#
# In addition to subsetting the features, other preprocessing steps have been taken. For example, some categorical variables have had their number of unique values reduced.
#
# We refer to the data as *simulated* because sampling was used to turn what was originally an ordinal response variable (42 income brackets) into something more continous.
#
# Considering this, the results of your analysis should be viewed skeptically. You can view the the preprocessing steps taken to create the simplified, simulated data in `data/preprocessing.ipynb`.
#
# **NOTE:** Variables have been renamed for easier interpretation. You can find the original variable names in the preprocessing notebook. It will be these original variable names that appear in the data dictionary linked above.

# %% [markdown]
# ### Features
# - **age** - Age of person
# - **hourly_pay** - Hourly salary of person (-1 if person is not payed by the hour)
# - **hours_per_week** - Number of hours usually worked per week
# - **weeks_worked** - Number of weeks worked per year
#
# - **sex** - {'Female': 0,'Male': 1}
# - **marital_status** - {'married':0,'widowed':1,'Divorced':2, 'Separated':3,'Never married':4}
# - **military_service** - {'has not served in the US armed forces':0,'has served in the US armed forces':1}
# - **student_status** - {'Not currently studying':0,'Enrolled full-time':1, 'Enrolled part-time':1}
# - **education** - {'Not finished high school': 0, 'High school': 1, 'Associate degree': 2, 'Bachelor\'s': 3, ,'Master\'s': 4,'Professional school degree': 5', Doctorate': 6}
#
# - **race** - {'White': 0, 'Black': 1, 'American Indian, Alaskan Native only (AI)': 2, 'Asian': 3, ,'Hawaiian, Pacific Islander (HP)': 4,'White-Black': 5', 'White-AI': 6, 'White-Asian': 7, 'White-HP': 8, 'Black-AI': 9, 'Black-Asian': 10, 'Black-HP': 11, 'AI-Asian': 12, 'AI-HP': 13, 'Asian-HP': 14, 'other race combinations': 15}
#
# - **industry** - Industry that the person is working in {'Other': 0, 'Agriculture, forestry, fishing, hunting': 1, 'Mining': 2, 'Construction': 3, ,'Manufacturing': 4,'Wholesale and retail trade': 5','Transportation and utilities': 6, 'Information': 7, 'Financial activities': 8, 'Professional and business services': 9, 'Education and health services': 10, 'Leisure and hospitality': 11, 'Other services': 12, 'Public administration': 13, 'Armed Forces': 14}
#
# - **occupation** - Occupation of person {'Other': 0, 'Management, business, and financial occ.': 1, 'Professional and related occ.': 2, 'Service occ.': 3, ,'Sales and related occ.': 4,'Office and administrative support occ.': 5','Farming, fishing and forestry': 6, 'Construction and extraction occ.': 7, 'Installation, maintenance and repair occ.': 8, 'Production occ.': 9, 'Transportation and material moving occ.': 10, 'Armed Forces': 11}
#
#
# - **income** - Annual income in dollars

# %% [markdown]
# <a id="part4questions"></a>
#
# ## <div class='exercise'><b>Question 4: Investigating trends [30 pts]</b></div>
#
# [Return to contents](#contents)
#
# Below we'll answer questions about potential trends in the data with the help of plots and/or simple statistics. Your goal should be to communicate your findings clearly. So be sure to provide an interpretation with your visualizations or other output.

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q4.1</b></div>

# %% [markdown]
# Is there a disparity in income of participants by gender? Consider using a log scale or another technique when plotting to communicate findings more clearly.

# %% [markdown]
# <font color = blue> The boxplot of income disparity by gender, using a log scale, reveals that males generally have higher incomes, with the male median income around the 75th percentile of female incomes (eyeball test). Additionally, the IQR for males is more concentrated and generally higher than that for females. This indicates a significant disparity. However, there are more outliers for females, suggesting greater variability and some high-income earners among women. These outliers highlight exceptions to the general trend of income differences between genders.</font>

# %%
# your code here
df = pd.read_csv('data/census_data.csv')
gendered_income = df[['income', 'sex']]

female = df[df['sex'] == 0]['income']
male = df[df['sex'] == 1]['income']

plt.figure(figsize=(10, 10))
plt.yscale('log')
plt.title("Income by Gender")
plt.xlabel("Gender")
plt.ylabel("Income (log scale)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.boxplot([female, male], tick_labels=['female', 'male'])
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q4.2</b></div>

# %% [markdown]
# Let's investigate a few questions about education and income:
# - Is there a relationship between income and education level?
#
# - Is this trend similar across both genders in the dataset?
#
# - Is it possible to consider education level as an ordinal variable? For instance, consider whether retaining the numerical ordering in the dataset might be preferable to education level as a categorical variable lacking order.

# %% [markdown]
# <font color = blue> Yes, it is possible to consider education level as an ordinal variable. Education levels inherently have a natural order, from "Not finished high school" to "Doctorate," which reflects increasing levels of educational attainment. This ordering can be useful in analyses where the progression of education is relevant, such as examining its impact on income. Retaining the numerical ordering allows for the use of statistical techniques that leverage this order, such as ordinal regression or calculating medians and percentiles. The graphs demonstrate that higher education levels generally correspond to higher incomes, supporting the use of education as an ordinal variable to capture these trends effectively.</font>
#
# <font color = blue> One caveat of considering education as an ordinal variable is that it implies that the interval between values is equal across the education spectrum. However, this is not the case when we consider the values beyond bachelor's, as we can observe diminisihing returns.
# </font>

# %%
# your code here

# Education Data
education_income = df[['income', 'education']]
education_labels = {
    0: 'Not finished high school',
    1: 'High school',
    2: "Associate's",
    3: "Bachelor's",
    4: "Master's",
    5: 'Professional school',
    6: 'Doctorate'
}

# Prepare data for bar chart
mean_income = df.groupby(['education', 'sex'])['income'].mean().unstack()

# Create a new figure for the side-by-side plots
fig, axs = plt.subplots(1, 2, figsize=(15, 8))

# Boxplot
axs[0].boxplot([df[df['education'] == i]['income'] for i in range(len(education_labels))])
axs[0].set_xticklabels(education_labels.values())
axs[0].set_yscale('log')
axs[0].set_title("Income by Education Level")
axs[0].set_xlabel("Education Level")
axs[0].set_ylabel("Income (log scale)")
axs[0].grid(axis='y', linestyle='--', alpha=0.7)
axs[0].tick_params(axis='x', rotation=45)

# Bar chart
mean_income.plot(kind='bar', ax=axs[1], width=0.8)
axs[1].set_title("Mean Income by Education Level and Gender")
axs[1].set_xlabel("Education Level")
axs[1].set_ylabel("Mean Income")
axs[1].tick_params(axis='x', rotation=45)

# Add legend
axs[1].legend(title="Gender")

plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q4.3</b></div>

# %% [markdown]
# Is there a clear trend between age and income?

# %% [markdown]
# <font color = blue> I believe there is a clear trend between income and age, and that relationship is not necessarily linear when considering all of the ages. Initially, I had just the plot on the left (below), but then I noticed that it was quickly increasing up to a point. After that point—which I think is around 45—the income decreases with age. To further investigate this significant point, I plotted two more graphs to confirm my suspicions.</font>

# %%
# your code here

# Prepare data for the plots
age_income = df[['income', 'age']]
age_mean_income = age_income.groupby('age')['income'].mean()

# Create a new figure for the side-by-side plots
fig, axs = plt.subplots(1, 3, figsize=(18, 6))

# Plot 1: All ages
axs[0].bar(age_mean_income.index, age_mean_income.values)
axs[0].set_title("Income by Age")
axs[0].set_xlabel("Age")
axs[0].set_ylabel("Income")
axs[0].grid(axis='y', linestyle='--', alpha=0.7)

# Plot 2: Ages up to 45
age_mean_income_up_to_45 = age_mean_income[age_mean_income.index <= 45]
axs[1].bar(age_mean_income_up_to_45.index, age_mean_income_up_to_45.values)
axs[1].set_title("Income by Age (up to 45)")
axs[1].set_xlabel("Age")
axs[1].set_ylabel("Income")
axs[1].grid(axis='y', linestyle='--', alpha=0.7)

# Plot 3: Ages greater than 45
age_mean_income_above_45 = age_mean_income[age_mean_income.index > 45]
axs[2].bar(age_mean_income_above_45.index, age_mean_income_above_45.values)
axs[2].set_title("Income by Age (above 45)")
axs[2].set_xlabel("Age")
axs[2].set_ylabel("Income")
axs[2].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q4.4</b></div>

# %% [markdown]
# Do any of the quantitative attributes show a clear relationship with income? If so, are these relationships linear or non-linear?

# %% [markdown]
# <font color = blue>As expected, there is a relationship between hours worked per week and income, but interestingly that relationship is not entirely linear. There appears to be a somewhat linear relationship between (roughly) 35-42 hours worked per week, but outside of that, the graph is relatively flat. It appears that around the 35 hour mark is when a baseline of \$40,000 can be earned.</font>
#
# <font color = blue>For hourly pay, there isn't an incredibly clear relationship. If there is, it would be weak.</font>
#
# <font color = blue>For number of weeks worked, there does appear a clear relationship, and that relationship can be stated as being linear (with modest certainty).</font>

# %%
# your code here
hours_pw_income = df[['income', 'hours_per_week']]
hours_pw_mean_income = hours_pw_income.groupby('hours_per_week')['income'].mean()

weeks_worked_income = df[['income', 'weeks_worked']]
weeks_worked_mean_income = weeks_worked_income.groupby('weeks_worked')['income'].mean()

hourly_pay_income = df[['income', 'hourly_pay']]
hourly_pay_mean_income = hourly_pay_income.groupby('hourly_pay')['income'].mean()

# Create a new figure for the vertically aligned plots
fig, axs = plt.subplots(3, 1, figsize=(10, 15))

# Plot 1: Income by Hours per Week
axs[0].bar(hours_pw_mean_income.index, hours_pw_mean_income.values)
axs[0].set_title("Income by Hours per Week")
axs[0].set_xlabel("Hours per Week")
axs[0].set_ylabel("Mean Income")
axs[0].grid(axis='y', linestyle='--', alpha=0.7)

# Plot 2: Income by Hourly Pay
axs[1].bar(hourly_pay_mean_income.index, hourly_pay_mean_income.values)
axs[1].set_title("Income by Hourly Pay")
axs[1].set_xlabel("Hourly Pay")
axs[1].set_ylabel("Mean Income")
axs[1].grid(axis='y', linestyle='--', alpha=0.7)

# Plot 3: Income by Weeks Worked
axs[2].bar(weeks_worked_mean_income.index, weeks_worked_mean_income.values)
axs[2].set_title("Income by Weeks Worked")
axs[2].set_xlabel("Weeks Worked")
axs[2].set_ylabel("Mean Income")
axs[2].grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q4.5</b></div>

# %% [markdown]
# What is the average effect of the `military_service` variable on income?

# %% [markdown]
# <font color = blue>It appears that individuals with military service generally have higher incomes. This is evident in the range, which shows both a higher minimum and maximum income compared to those without service. The median income for those with military service is also higher, and their interquartile income range is more concentrated at higher values. This suggests that military service may be associated with better income outcomes.</font>

# %%
# your code here
no_service = df[df['military_service'] == 0]['income']
service = df[df['military_service'] == 1]['income']

plt.figure(figsize=(8, 6))
plt.yscale('log')
plt.title("Income by Military Service")
plt.xlabel("Military Service")
plt.ylabel("Income (log scale)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.boxplot([no_service, service], tick_labels=['No Military Service', 'Military Service'])
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q4.6</b></div>

# %% [markdown]
# Propose a question of your own that you would like to explore in the data. Create a visualization to help you answer this question and provide an interpretation of your findings.

# %% [markdown]
# <h1 color = blue> How does income vary by industry? </h1>
#
# <font color = blue> The graphs illustrate income distribution across various industries and highlight gender disparities within those industries. The boxplot shows that income varies significantly by industry, with 'Mining' having the highest median income, followed by financial industries and 'Information.' The bar chart below reveals that, on average, men earn more than women across most industries. This disparity is particularly noticeable in industries such as "Manufacturing" and "Public Administrations." These visualizations underscore the importance of industry choice in income potential and highlight persistent gender income gaps, indicating a general disparity in pay by gender.</font>

# %%
# your code here

# Define industry labels with swapped key-value pairs
industry_labels = {
    0: 'Other',
    1: 'Agriculture, forestry, fishing, hunting',
    2: 'Mining',
    3: 'Construction',
    4: 'Manufacturing',
    5: 'Wholesale and retail trade',
    6: 'Transportation and utilities',
    7: 'Information',
    8: 'Financial activities',
    9: 'Professional and business services',
    10: 'Education and health services',
    11: 'Leisure and hospitality',
    12: 'Other services',
    13: 'Public administration',
    14: 'Armed Forces'
}

# Prepare data for the boxplot
industry_income = df[['income', 'industry']]
income_by_industry = [industry_income[industry_income['industry'] == code]['income'] for code in industry_labels.keys()]

# Prepare data for the bar chart by gender
grouped_data = df.groupby(['industry', 'sex'])['income'].mean().unstack()

# Create a new figure for the plots
fig, axs = plt.subplots(2, 1, figsize=(10, 14))

# Boxplot of income by industry
axs[0].boxplot(income_by_industry, tick_labels=industry_labels.values())
axs[0].set_title("Income Distribution by Industry")
axs[0].set_xlabel("Industry")
axs[0].set_ylabel("Income")
axs[0].grid(axis='y', linestyle='--', alpha=0.7)
axs[0].tick_params(axis='x', rotation=90)

# Bar chart of mean income by industry and gender
grouped_data.plot(kind='bar', ax=axs[1], width=0.8)
axs[1].set_title("Mean Income by Industry and Gender")
axs[1].set_xlabel("Industry")
axs[1].set_ylabel("Mean Income")
axs[1].tick_params(axis='x', rotation=90)
axs[1].set_xticklabels(industry_labels.values())
axs[1].legend(title="Gender", labels=["Female", "Male"])

plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <a id="part5questions"></a>
#
# ## <div class='exercise'><b>Question 5:  Calculate the Gini coefficient [10 pts]</b></div>
#
# [Return to contents](#contents)
#
#
# **Gini coefficients are often used to quantify income inequality.** For an introductory overview of the Gini coefficient, its derivation, and its uses, you can [read more about it here](https://en.wikipedia.org/wiki/Gini_coefficient). That article also provides [a useful graphical representation](https://en.wikipedia.org/wiki/File:Economics_Gini_coefficient2.svg) of the Gini coefficient to better understand how it measures inequality.
#
# The Gini coefficient is defined by the formula:
#
# $$G = \dfrac{ \sum_{i=1}^{n} (2i - n - 1) x_i}{n  \sum_{i=1}^{n} x_i}$$
#
# where $x$ is an observed value, $n$ is the number of values observed and $i$ is the rank of values in **ascending** order.
#
# A Gini coefficient of $G=0$ implies perfect income equality, whereas a Gini coefficient close to $G=1$ implies a concentration of wealth among the richest few.

# %% [markdown]
# <div class='exercise'><b>Q5.1</b></div>

# %% [markdown]
# Based on the above formula, calculate and report the Gini coefficient for the income of those people in the the provided ASEC dataset. Store the result in `gini_coef`.
#
# - **NOTE:** For algorithmic simplicity and consistency, you can rank income values for all observations, keeping duplicate values in your sorted array. Therefore, you will likely have sorted income values $x_i$ similar to `[417, 417, 417, ..., 250000, 250000, 250000]` with corresponding rank indices $i$ similar to `[1, 2, 3, ..., 12353, 12354, 12355]`. Nothing more sophisticated than that is required for dealing with ties (i.e. duplicates) in your sorted income values for Question 5.1.

# %%
# your code here
income_sorted = sorted(df['income'].values)
n = len(income_sorted)
numerator = 0
for i in range(n):
    numerator += (2 * i - n - 1) * income_sorted[i]
denominator = n * sum(income_sorted)
gini_coef = numerator / denominator

# %%
# Print resulting Gini coefficient
print(f"The Gini Index for this dataset is {gini_coef:.3f}")
# Out:
# The Gini Index for this dataset is 0.448

# %%
grader.check("q5.1")
# Out:
# q5.1 results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q5.2</b></div>

# %% [markdown]
# According to the [World Bank estimate](https://www.indexmundi.com/facts/indicators/SI.POV.GINI/rankings) the country with the largest Gini coefficient is South Africa, ranked 1st at $0.63$, while the lowest is the Slovak Republic, ranked 162nd at $0.232$. The United States is ranked 46th on the list and has a Gini index of $0.415$.
#
# - How well does your calculated Gini coefficient for this simulated dataset match the world bank estimate?
#
# - Might the self-report nature of the data, preprocessing steps, or simulation (i.e., sampling) procedure have affected your results? If so, how?
#
# **Note:** The World Bank estimate website uses a [0,100] range for the Gini Index. Above we have converted this to a [0,1] range.

# %% [markdown]
# <font color = blue> The calculated Gini coefficient of 0.448 for the United States in your simulated dataset closely aligns with the World Bank's estimate of 0.41, suggesting a similar degree of income inequality (\~10\% difference) . However, discrepancies might arise due to the self-reported nature of the data, which can introduce biases if individuals misreport their income. For example, some people might report having lower income then they actually do to avoid higher taxes, and some people might report higher income to pretend they have more wealth. Preprocessing steps, such as handling missing data or outliers, can also affect the accuracy of the Gini calculation by altering the income distribution. </font>
#
# <font color = blue>Additionally, the simulation or sampling procedure might not fully capture the complexity and diversity of real-world income distributions, leading to potential variations from actual estimates. As an example, our sample may have contained more outliers, whereas the full dataset would dilute the effects of these outliers. These factors highlight the importance of careful data handling and validation when comparing simulated results to established benchmarks.</font>

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <a id="part6questions"></a>
#
# ## <div class='exercise'><b>Question 6:  Critiquing the simulated data [10 pts]</b></div>
#
# [Return to contents](#contents)

# %% [markdown]
# Take a look at both the [data dictionary for the original dataset](https://www2.census.gov/programs-surveys/cps/datasets/2024/march/asec2024_ddl_pub_full.pdf) and the notebook used to create the simplified simulation, `data/preprocessing.ipynb`.
#
# What might you have done differently were you to write your own preprocessing code?
# A nonexhaustive list of a few things to consider would be:
# - Are there important features you think should have been included that were not?
# - Do you agree with the methods used to reduce the number of unique categorical values?
# - Might there be a better way to simulate a continuous response from the discrete income brackets in the original data?
#
# **Note:** We used the record type 'person' data from the ASEC rather than 'household' or 'family.' All three record types are represented in the data dictionary.

# %% [markdown]
# > **Note**: The rubric below is provided for transparency. Please ensure your responses are genuine and thoughtful, rather than simply attempting to "fit" the rubric.
# ---
# <details>
# <summary><b>Click to view the Q6 Critique Rubric</b></summary>
#
# ### Q6 Critique Rubric:
#
# **Total Points: 10**
#
# #### 1. Relevance of Comments (4 points):
# - **4 points**: The critique directly addresses specific sections or steps in the preprocessing notebook, demonstrating a thorough understanding of the content.
# - **3 points**: The critique references multiple sections of the notebook with some specificity.
# - **2 points**: The critique generally addresses the notebook but may lack specific references to steps or sections.
# - **1 point**: The critique provides only a cursory overview without specific details.
# - **0 points**: The critique does not address the preprocessing notebook.
#
# #### 2. Depth of Analysis (4 points):
# - **4 points**: The student provides deep insights, identifies potential pitfalls, or suggests meaningful improvements for multiple sections of the notebook.
# - **3 points**: The student provides valuable feedback for one section or multiple but less detailed feedback for several sections.
# - **2 points**: The analysis is somewhat detailed but may lack depth or actionable feedback.
# - **1 point**: The feedback is generic or surface-level.
# - **0 points**: No meaningful analysis provided.
#
# #### 3. Clarity and Organization (2 points):
# - **2 points**: The critique is well-organized, clear, and easy to follow.
# - **1 point**: The critique is somewhat organized but may have unclear sections.
# - **0 points**: The critique is disorganized or difficult to understand.
#
# ---
#
# Remember to provide specific examples or suggestions whenever possible. General statements without backing evidence or examples will not be as valuable as those with clear references and reasoning.
#
# </details>

# %% [markdown]
# <font color = blue>In the preprocessing process, feature engineering was applied to create or modify features to enhance the model. For instance, the "education" feature was transformed into an ordinal variable with numerical values representing different education levels, such as high school (1) and bachelor's degree (3). However, during data filtering, certain subsets were selected that might reduce the dataset's representation of the full population. For example, individuals under 18 were excluded with the code `df = df[df.person_record != 1) & (df.age >= 18)]`, potentially omitting high school dropouts who could be working full-time, thus making the data less comprehensive. While this helps filter out non-working students and children, it could skew income statistics for certain groups.}</font>
#
# <font color = blue>Additionally, data reduction methods, like merging multiple "race" categories into broader groups, simplify analysis but may overlook specific subgroup identities—such as Southeast Asian. This approach also applies to gender, where defining it as male and female might exclude non-binary individuals. While simplifying categorical values can streamline data processing, it's crucial to ensure these reductions don't lead to significant information loss or introduce biases.</font>
#
# <font color = blue>If I were to enhance the preprocessing, I would consider including geographical location within the U.S., such as state or county data, to explore regional income variations and demographic distributions. As a diligent reader of the Wall Street Journal, I am interested in comparing income with economic metrics like GDP and its growth. Incorporating unemployment and inflation data could also provide insights into economic trends over time. Lastly, while a basic random sampling method was used, fitting statistical distributions to original income data or stratified samplying might yield a more accurate representation of real-world income distributions.</font>

# %% [markdown]
# <!-- END QUESTION -->
#
# <div class="alert alert-info" style="color: #4a4a4a; background-color: #fbe8ff; border-color: #eed4db; border-width: 1px; border-radius: 3px; padding: 10px;">
#
# **Wrap-up**
#
# * Please describe the aspect(s) of the assignment you found most challenging. This could be conceptual and/or related to coding and implementation. This is also a good place to ask any remaining questions you may have.
#
# * How many hours did you spend working on this assignment? Store this as an int or float in `hours_spent_on_hw`. If you worked on the project in a group, report the *average* time spent per person.
#
# </div>

# %%
hours_spent_on_hw = 10

# %%
grader.check("wrapup")
# Out:
# wrapup results: All test cases passed!

# %%
notebook_end = time.time()
print(f"It took {(notebook_end - notebook_start)/60:.2f} minutes for this notebook to run")
# Out:
# It took 0.05 minutes for this notebook to run

# %% [markdown]
# 🌈 **This concludes HW2. Thank you!**
#
# [Return to contents](#contents)
